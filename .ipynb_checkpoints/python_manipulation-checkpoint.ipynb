# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
rand_list1 = [np.random.randint(1,100) for x in range(16)]
rand_list2 = [np.random.randint(1,100) for x in range(16)]
rand_array1 = np.random.randint(1, 10, size=(4, 4))
rand_array2 = np.random.randint(1, 10, size=(4, 4))

# %%
list_average = np.average(rand_list)
list_stdev = np.std(rand_list)
array_average = np.average(rand_array)
array_stdev = np.std(rand_array)

# %%
fig, ax = plt.subplots()
ax.scatter(rand_list, rand_list2)
ax.set_ylabel('rand_list')
ax.set_xlabel('rand_list2')
ax.set_title('random list comparison')
plt.savefig('rand_list_scatter.png')
